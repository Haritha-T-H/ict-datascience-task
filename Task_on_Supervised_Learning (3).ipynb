# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading dataset
data= pd.read_csv('/content/Salary_dataset.csv')

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
#droping column unnamed:0
data= data.drop(['Unnamed: 0'], axis=1)

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
#shape of dataset
data.shape
# Out:
# (30, 2)

# %%
#info of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
#describe dataset
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
#check for null values
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#spliting in x and y
y = data['Salary']
x = data.drop(['Salary'],axis=1)

# %%
y.shape
# Out:
# (30,)

# %%
#from sklearn importing train split and Linear regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Spliting x and y into training and test dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.head()
# Out:
#     YearsExperience
# 28             10.4
# 24              8.8
# 12              4.1
# 0               1.2
# 4               2.3

# %%
#training the model
reg=LinearRegression()
model=reg.fit(x_train, y_train)

# %%
#predicting values for test dataset
y_pred=model.predict(x_test)
y_pred
# Out:
# array([115791.21011287,  71499.27809463, 102597.86866063,  75268.80422384,
#         55478.79204548,  60190.69970699])

# %%
#checking the model performance
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r_score = r2_score(y_test, y_pred)
print("Mean Squared Error :", mse)
print("Mean Absolute Error :", mae)
print("R2 Score :", r_score)
# Out:
# Mean Squared Error : 49830096.855908394
# Mean Absolute Error : 6286.453830757745
# R2 Score : 0.9024461774180497

# %% [markdown]
# The model has a R2 score closer to 1 and MSE, MAE has a higher value.

# %%
#function to predict for new data
def predict_salary(years):
  x=np.array([years])
  x=x.reshape(1,-1)
  y_pred=model.predict(x)
  return y_pred[0].round(2)

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
print(f'The predicted salary:{predict_salary(2.3)}')
# Out:
# The predicted salary:46054.98
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
